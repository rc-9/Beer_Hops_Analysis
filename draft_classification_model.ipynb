# %% [markdown]
# # Beer Hops Data: Classification Model with Extreme-Gradient Boosting Algorithm (XG-Boost)
#
# **Data Files:** *cln_hops_profile.csv, cln_hops_brewvalues.csv*
#
# **Original Source:** *https://beermaverick.com/hops/*  (Data retrieved via web-scraping)
#
# ------------------------------------------------------------

# %% [markdown]
# ### Setup
#
# **Objective:** Import necessary modules for machine-learning models & visualization and read in CSV files into local dataframes for easier access.

# %%
# Import necessary packages
import numpy as np
import pandas as pd
import itertools
import folium
import functools
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Read in raw CSV data into local dataframes
CLEAN_HOPS_PATH = './clean_data/cln_hops_brewvalues.csv'  
CLEAN_HOPS_PROFILE_PATH = './clean_data/cln_hops_profile.csv'
hop_values_df = pd.read_csv(CLEAN_HOPS_PATH, index_col='Hop Name')
hop_profile_df = pd.read_csv(CLEAN_HOPS_PROFILE_PATH, index_col='Hop Name')

# Create a master dataframe indexed on hop name
master_df = hop_values_df.merge(hop_profile_df, left_index=True, right_index=True)

master_df
# Out:
#                      Alpha Acid % - Min  Alpha Acid % - Max  \
# Hop Name
# Astra                               7.0                10.0
# Eclipse                            15.7                19.0
# Ella                               13.3                19.2
# Enigma                             13.5                19.4
# Feux-Coeur Francais                12.0                16.0
# ...                                 ...                 ...
# Zappa                               6.0                 9.0
# Zenia                              11.0                14.0
# Zenith                              9.0                11.0
# Zeus                               13.0                17.5
# Zythos                             10.0                12.5
#
#                      Alpha Acid % - Avg  Beta Acid % - Min  Beta Acid % - Max  \
# Hop Name
# Astra                               8.5                4.0                6.0
# Eclipse                            17.4                5.9                9.0
# Ella                               16.3                4.0                7.8
# Enigma                             16.5                4.5                7.1
# Feux-Coeur Francais                14.0                3.1                6.0
# ...                                 ...                ...                ...
# Zappa                               7.5                8.0                9.0
# Zenia                              12.5                4.4                5.1
# Zenith                             10.0                NaN                NaN
# Zeus                               15.3                4.0                6.5
# Zythos                             11.3                4.7                6.2
#
#                      Beta Acid % - Avg  Alpha-Beta Ratio - Min  \
# Hop Name
# Astra                              5.0                     1.0
# Eclipse                            7.5                     2.0
# Ella                               5.9                     2.0
# Enigma                             5.8                     2.0
# Feux-Coeur Francais                4.6                     2.0
# ...                                ...                     ...
# Zappa                              8.5                     1.0
# Zenia                              4.8                     2.0
# Zenith                             3.0                     inf
# Zeus                               5.3                     2.0
# Zythos                             5.5                     2.0
#
#                      Alpha-Beta Ratio - Max  Alpha-Beta Ratio - Avg  \
# Hop Name
# Astra                                   3.0                     2.0
# Eclipse                                 3.0                     2.0
# Ella                                    5.0                     3.0
# Enigma                                  4.0                     3.0
# Feux-Coeur Francais                     5.0                     4.0
# ...                                     ...                     ...
# Zappa                                   1.0                     1.0
# Zenia                                   3.0                     3.0
# Zenith                                  4.0                     inf
# Zeus                                    4.0                     3.0
# Zythos                                  3.0                     2.0
#
#                      Co-Humulone as % of Alpha - Min  ...  violet  watermelon  \
# Hop Name                                              ...
# Astra                                           26.0  ...   False       False
# Eclipse                                         33.0  ...   False       False
# Ella                                            33.0  ...   False       False
# Enigma                                          37.0  ...   False       False
# Feux-Coeur Francais                              NaN  ...     NaN         NaN
# ...                                              ...  ...     ...         ...
# Zappa                                           40.0  ...   False       False
# Zenia                                            NaN  ...   False       False
# Zenith                                           NaN  ...   False       False
# Zeus                                            28.0  ...   False       False
# Zythos                                          28.0  ...   False       False
#
#                      whiskey  white_grape  white_wine   wild   wine  woody  \
# Hop Name
# Astra                  False        False        True  False  False  False
# Eclipse                False        False       False  False  False  False
# Ella                   False        False       False  False  False  False
# Enigma                 False        False        True  False  False  False
# Feux-Coeur Francais      NaN          NaN         NaN    NaN    NaN    NaN
# ...                      ...          ...         ...    ...    ...    ...
# Zappa                  False        False       False  False  False  False
# Zenia                  False        False       False  False  False  False
# Zenith                 False        False       False  False  False  False
# Zeus                   False        False       False  False  False  False
# Zythos                 False        False       False  False  False  False
#
#                      yogurt   zest
# Hop Name
# Astra                 False  False
# Eclipse               False  False
# Ella                  False  False
# Enigma                False  False
# Feux-Coeur Francais     NaN    NaN
# ...                     ...    ...
# Zappa                 False  False
# Zenia                 False  False
# Zenith                False  False
# Zeus                  False  False
# Zythos                False  False
#
# [304 rows x 200 columns]

# %% [markdown]
# ### Pre-Processing
#
# **Objective:** Prepare dataframe to be fed into boosting model with desired predictor variables of interest in the necessary formats.

# %%
df = hop_values_df.copy()
regions = {
'Australia': 'Australia',
'Canada': 'North America',
'China': 'Asia',
'Czech Republic': 'Europe',
'France': 'Europe',
'Germany': 'Europe',
'Japan': 'Asia',
'New Zealand': 'Australia',
'Poland': 'Europe',
'Slovenia': 'Europe',
'South Africa': 'Africa',
'Ukraine': 'Europe',
'United Kingdom': 'Europe',
'United States of America': 'North America'
}
df['Region'] = hop_profile_df.Country.map(lambda x: regions[x])

# Remove records of Asia (EDA script showed low amount of hops from China/Japan relative to other countries)
df = df[df['Region'] != 'Asia']

df.replace(float('inf'), np.nan, inplace=True)
df.isna().sum()

df.drop(columns=[
    'Alpha Acid % - Min',
    'Alpha Acid % - Max',
#     'Alpha Acid % - Avg',
    'Beta Acid % - Min',
    'Beta Acid % - Max',
#     'Beta Acid % - Avg',
    'Alpha-Beta Ratio - Min',
    'Alpha-Beta Ratio - Max',
#     'Alpha-Beta Ratio - Avg',
    'Co-Humulone as % of Alpha - Min',
    'Co-Humulone as % of Alpha - Max',
#     'Co-Humulone as % of Alpha - Avg',
    'Total Oils (mL/100g) - Min',
    'Total Oils (mL/100g) - Max',
#     'Total Oils (mL/100g) - Avg',
    'Myrcene - Min',
    'Myrcene - Max',
#     'Myrcene - Avg',
    'Humulene - Min',
    'Humulene - Max',
#     'Humulene - Avg',
    'Caryophyllene - Min',
    'Caryophyllene - Max',
#     'Caryophyllene - Avg',
    'Farnesene - Min',
    'Farnesene - Max',
#     'Farnesene - Avg',
    'Other Oils - Min',
    'Other Oils - Max'
], inplace=True)

for i in df.columns:
    print(i)
    print(df.groupby('Region')[i].describe())
    print('----------------------------')
# Out:
# Alpha Acid % - Avg
#                count       mean       std  min     25%   50%     75%   max
# Region
# Africa          10.0  12.280000  2.880895  5.5  12.025  12.5  13.875  15.4
# Australia       38.0  11.371053  4.435843  3.0   7.625  11.6  14.300  18.5
# Europe         109.0   7.831193  3.451964  2.2   5.000   7.3  10.000  20.5
# North America  142.0   9.772535  4.062214  1.2   6.500   9.7  13.000  18.5
# ----------------------------
# Beta Acid % - Avg
#                count      mean       std  min   25%  50%    75%   max
# Region
# Africa          10.0  5.550000  1.162612  3.8  4.95  5.4  5.800   8.1
# Australia       37.0  6.186486  1.408538  3.5  5.00  6.0  7.300   9.0
# Europe         107.0  4.876636  1.909884  1.8  3.80  4.5  5.500  12.5
# North America  138.0  5.346377  1.723185  1.5  4.00  5.1  6.275  10.5
# ----------------------------
# Alpha-Beta Ratio - Avg
#                count      mean       std  min  25%  50%  75%  max
# Region
# Africa           9.0  2.555556  0.726483  1.0  2.0  3.0  3.0  3.0
# Australia       37.0  1.945946  0.743339  1.0  1.0  2.0  2.0  4.0
# Europe         104.0  1.971154  0.897210  0.0  1.0  2.0  2.0  5.0
# North America  120.0  2.133333  1.036586  0.0  1.0  2.0  3.0  6.0
# ----------------------------
# Co-Humulone as % of Alpha - Avg
#                count       mean       std   min    25%    50%     75%   max
# Region
# Africa          10.0  27.300000  5.652925  21.0  23.00  27.00  29.125  39.5
# Australia       36.0  31.236111  7.870820  21.5  24.75  29.50  36.625  54.0
# Europe         105.0  27.526667  6.484794   2.3  23.50  27.50  31.000  44.5
# North America  118.0  31.061017  7.800559  13.5  25.00  30.75  35.875  53.0
# ----------------------------
# Total Oils (mL/100g) - Avg
#                count      mean       std  min    25%   50%  75%  max
# Region
# Africa           9.0  1.066667  0.324037  0.6  0.900  1.00  1.3  1.6
# Australia       36.0  1.711111  0.686514  0.8  1.200  1.55  2.0  3.5
# Europe         109.0  1.422936  0.672286  0.5  0.900  1.40  1.8  4.5
# North America  128.0  1.715625  0.783535  0.3  1.175  1.60  2.1  4.0
# ----------------------------
# Myrcene - Avg
#                count       mean        std   min    25%   50%     75%   max
# Region
# Africa           9.0  31.388889   9.040803  22.5  24.00  32.5  35.000  50.0
# Australia       33.0  38.227273  15.020866   3.0  32.00  38.0  50.000  68.5
# Europe          93.0  39.209677  13.154666  11.5  30.00  37.5  47.500  71.0
# North America  104.0  46.076923  11.914088  10.0  39.25  47.5  53.625  70.0
# ----------------------------
# Humulene - Avg
#                count       mean        std  min     25%    50%     75%   max
# Region
# Africa           9.0  22.444444   7.588826  3.0  22.500  25.00  25.500  28.0
# Australia       34.0  19.117647  13.062820  1.0  10.125  16.50  28.375  50.0
# Europe          90.0  22.564444  11.762665  1.3  15.250  21.25  30.000  55.5
# North America  100.0  18.470000  10.501039  0.5  11.500  16.75  21.750  57.0
# ----------------------------
# Caryophyllene - Avg
#                count       mean       std  min  25%    50%   75%   max
# Region
# Africa           9.0  10.722222  2.476276  6.0  9.5  10.50  12.0  14.0
# Australia       33.0   8.787879  4.496579  2.0  6.5   9.00  10.5  27.5
# Europe          76.0   8.526316  4.174442  0.5  6.0   8.25  10.5  26.5
# North America   99.0   9.146465  3.648632  0.5  7.0   9.00  11.0  27.0
# ----------------------------
# Farnesene - Avg
#                count      mean        std  min  25%  50%    75%    max
# Region
# Africa           9.0  5.444444   4.772607  0.5  0.5  6.0  9.500   13.0
# Australia       33.0  3.636364   5.575158  0.5  0.5  0.5  5.000   25.0
# Europe          88.0  4.753409  11.782824  0.5  0.5  0.5  5.625  103.0
# North America  101.0  2.000000   3.496427  0.5  0.5  0.5  0.500   17.0
# ----------------------------
# Region
#               count unique            top freq
# Region
# Africa           10      1         Africa   10
# Australia        38      1      Australia   38
# Europe          109      1         Europe  109
# North America   142      1  North America  142
# ----------------------------

# %%
# Separate the dependent variable (outcome we want to predict) from the independent predictors
# X_data = master_df.copy()
master_df.dropna(inplace=True)
Y_data = master_df.Country.copy()
X_data = master_df.select_dtypes(exclude="number").copy()
X_data.drop(columns=['Country', 'Purpose'], inplace=True)
X_data = X_data.astype(int)

# Keep only one metric for each brew value (avg)
X_data.drop(columns=[
#     'Country',  # dropping the outcome variable 
#     'Alpha Acid % - Min',
#     'Alpha Acid % - Max',
#     'Alpha Acid % - Avg',
#     'Beta Acid % - Min',
#     'Beta Acid % - Max',
#     'Beta Acid % - Avg',
#     'Alpha-Beta Ratio - Min',
#     'Alpha-Beta Ratio - Max',
#     'Alpha-Beta Ratio - Avg',
#     'Co-Humulone as % of Alpha - Min',
#     'Co-Humulone as % of Alpha - Max',
#     'Co-Humulone as % of Alpha - Avg',
#     'Total Oils (mL/100g) - Min',
#     'Total Oils (mL/100g) - Max',
#     'Total Oils (mL/100g) - Avg',
#     'Myrcene - Min',
#     'Myrcene - Max',
#     'Myrcene - Avg',
#     'Humulene - Min',
#     'Humulene - Max',
#     'Humulene - Avg',
#     'Caryophyllene - Min',
#     'Caryophyllene - Max',
#     'Caryophyllene - Avg',
#     'Farnesene - Min',
#     'Farnesene - Max',
#     'Farnesene - Avg',
#     'Other Oils - Min',
#     'Other Oils - Max'
], inplace=True)

# %%
X_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, Eclipse to Zythos
# Columns: 169 entries, alfalfa to zest
# dtypes: int64(169)
# memory usage: 243.0+ KB

# %%
X_data.fillna(np.nan, inplace=True)
X_data.reset_index(drop=True)
Y_data.reset_index(drop=True)
# Out:
# 0                     Australia
# 1                     Australia
# 2                     Australia
# 3                     Australia
# 4                     Australia
#                  ...
# 178    United States of America
# 179    United States of America
# 180    United States of America
# 181    United States of America
# 182    United States of America
# Name: Country, Length: 183, dtype: object

# %% [markdown]
# ### Data-Partitioning
#
# **Objective:** Split dataset to prepare a training set and a testing set to be able to fit a model and evaluate its performance.

# %%
# Split X & Y data as per desired specifications
X_train, X_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=123)

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 146
# 37
# 146
# 37

# %% [markdown]
# ### Model Fitting
#
# **Objective:** Execute boosting algorithm to train model & predict the country categorical variable on the test dataset.

# %%
# Instantiate classifier object and fit the training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# /home/rc-ub/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:31:53] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=12,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
# Apply model on test set to make country predictions
y_pred = model.predict(X_test)
predictions = [value for value in y_pred]

# %% [markdown]
# ### Model Evaluation
#
# **Objective:** Evaluate model based on the test data set results.

# %%
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 29.73%

# %%
#########################################################################################

# %%
regions = {
'Australia': 'Australia',
'Canada': 'North America',
'China': 'Asia',
'Czech Republic': 'Europe',
'France': 'Europe',
'Germany': 'Europe',
'Japan': 'Asia',
'New Zealand': 'Austrailia',
'Poland': 'Europe',
'Slovenia': 'Europe',
'South Africa': 'Africa',
'Ukraine': 'Europe',
'United Kingdom': 'Europe',
'United States of America': 'North America'
}

prof_df = hop_profile_df.copy()
prof_df.dropna(inplace=True)
countries = prof_df.Country.copy()
prof_df.drop(columns=['Country', 'Purpose'], inplace=True)
prof_df = prof_df.astype(int)
prof_df['Country'] = countries

master_df = hop_values_df.merge(prof_df, left_index=True, right_index=True)
master_df.Country = master_df.Country.map(lambda x: regions[x])

# %%
# Separate the dependent variable (outcome we want to predict) from the independent predictors
master_df.dropna(inplace=True)
X_data = master_df.copy()
Y_data = master_df.Country.copy()
# X_data = master_df.select_dtypes(include="number").copy()



# Keep only one metric for each brew value (avg)
X_data.drop(columns=[
    'Country',  # dropping the outcome variable 
#     'Alpha Acid % - Min',
#     'Alpha Acid % - Max',
#     'Alpha Acid % - Avg',
#     'Beta Acid % - Min',
#     'Beta Acid % - Max',
#     'Beta Acid % - Avg',
#     'Alpha-Beta Ratio - Min',
#     'Alpha-Beta Ratio - Max',
#     'Alpha-Beta Ratio - Avg',
#     'Co-Humulone as % of Alpha - Min',
#     'Co-Humulone as % of Alpha - Max',
#     'Co-Humulone as % of Alpha - Avg',
#     'Total Oils (mL/100g) - Min',
#     'Total Oils (mL/100g) - Max',
#     'Total Oils (mL/100g) - Avg',
#     'Myrcene - Min',
#     'Myrcene - Max',
#     'Myrcene - Avg',
#     'Humulene - Min',
#     'Humulene - Max',
#     'Humulene - Avg',
#     'Caryophyllene - Min',
#     'Caryophyllene - Max',
#     'Caryophyllene - Avg',
#     'Farnesene - Min',
#     'Farnesene - Max',
#     'Farnesene - Avg',
#     'Other Oils - Min',
#     'Other Oils - Max'
], inplace=True)

# %%
X_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, Eclipse to Zythos
# Columns: 198 entries, Alpha Acid % - Min to zest
# dtypes: float64(29), int64(169)
# memory usage: 284.5+ KB

# %%
# X_data.fillna(np.nan, inplace=True)
X_data.reset_index(drop=True)
Y_data.reset_index(drop=True)
# Out:
# 0          Australia
# 1          Australia
# 2          Australia
# 3          Australia
# 4          Australia
#            ...
# 178    North America
# 179    North America
# 180    North America
# 181    North America
# 182    North America
# Name: Country, Length: 183, dtype: object

# %% [markdown]
# ### Data-Partitioning
#
# **Objective:** Split dataset to prepare a training set and a testing set to be able to fit a model and evaluate its performance.

# %%
# Split X & Y data as per desired specifications
X_train, X_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=123)

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 146
# 37
# 146
# 37

# %% [markdown]
# ### Model Fitting
#
# **Objective:** Execute boosting algorithm to train model & predict the country categorical variable on the test dataset.

# %%
# Instantiate classifier object and fit the training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# /home/rc-ub/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:40:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=12,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
# Apply model on test set to make country predictions
y_pred = model.predict(X_test)
predictions = [value for value in y_pred]

# %% [markdown]
# ### Model Evaluation
#
# **Objective:** Evaluate model based on the test data set results.

# %%
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 59.46%
